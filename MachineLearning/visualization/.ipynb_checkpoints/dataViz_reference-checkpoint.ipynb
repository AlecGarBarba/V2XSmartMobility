# %%
import numpy as np  # scientific computation
import pandas as pd # primary data structure library
import matplotlib.pyplot as plt #primary plotting stricture

from datetime import datetime, timedelta
#Data visualization
from matplotlib import pyplot
import matplotlib.pyplot as plt
import folium # map generator.

# %%
parkdf= pd.read_csv('rec_csv_file_park_1.csv')
size = parkdf.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), parkdf['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), parkdf['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), parkdf['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')


axs[0].set_ylim(( -0.5,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
parkdf= pd.read_csv('rec_csv_file_plain_street_1.csv') 
size = parkdf.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), parkdf['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), parkdf['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), parkdf['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')


axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
parkdf= pd.read_csv('rec_csv_file_plain_street_2.csv') 
size = parkdf.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), parkdf['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), parkdf['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), parkdf['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')


axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
parkdf= pd.read_csv('rec_csv_file_plain_street_3.csv') 
size = parkdf.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), parkdf['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), parkdf['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), parkdf['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')


axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
prkdf= pd.read_csv('rec_csv_file_plain_street_3_2.csv') 
size = prkdf.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), prkdf['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), prkdf['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), prkdf['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')


axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
parkdf= pd.read_csv('rec_csv_file_plain_baches_street_1.csv') 
size = parkdf.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), parkdf['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), parkdf['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), parkdf['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
parkdf= pd.read_csv('rec_csv_file_plain_baches_street_2.csv') 
size = parkdf.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), parkdf['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), parkdf['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), parkdf['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
parkdf= pd.read_csv('rec_csv_file_plain_baches_street_3_2.csv') 
size = parkdf.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), parkdf['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), parkdf['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), parkdf['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
parkdf= pd.read_csv('rec_csv_file__tope_1.csv') 
size = parkdf.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), parkdf['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), parkdf['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), parkdf['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
parkdf= pd.read_csv('rec_csv_file__curva_1.csv') 
size = parkdf.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), parkdf['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), parkdf['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), parkdf['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
parkdf= pd.read_csv('rec_csv_file__curva_2.csv') 
size = parkdf.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), parkdf['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), parkdf['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), parkdf['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
parkdf= pd.read_csv('rec_csv_file__curva_3.csv') 
size = parkdf.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time] - Curva 3')
axs[0].plot(range(0,size), parkdf['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), parkdf['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), parkdf['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %% [markdown]
# ## Creating a healthy dataset, without any anomaly on the road

# %%
parkdf= pd.read_csv('rec_csv_file_park_1.csv',usecols=['Ax','Ay','Az'])
df_plain_1= pd.read_csv('rec_csv_file_plain_street_1.csv',usecols=['Ax','Ay','Az'])  #until 410
df_plain_1= df_plain_1.head(410)
df_plain_1_1 = df_plain_1.head(300)
df_plain_1_2 = df_plain_1.tail(110)
df_plain_2= pd.read_csv('rec_csv_file_plain_street_2.csv',usecols=['Ax','Ay','Az'])  #completo
df_plain_3= pd.read_csv('rec_csv_file_plain_street_3.csv',usecols=['Ax','Ay','Az'])  #completo. Es el más ruidoso
df_plain_3= df_plain_3.tail(240)
df_plain_4= pd.read_csv('rec_csv_file_plain_street_3_2.csv',usecols=['Ax','Ay','Az'])

# %%
frames = []
frames = [parkdf, df_plain_1,df_plain_3,df_plain_4,df_plain_2, parkdf[:30],df_plain_4,df_plain_2[50:],df_plain_3[:100],parkdf[:20],df_plain_2,df_plain_4,df_plain_3[:150],df_plain_1]

# %% [markdown]
# ## Creating replications of each healthy frame

# %%
count = 0
for frame in frames:
    while frame.shape[0] < 300:
        frame = pd.concat([frame,frame])
    frame = frame.head(300)
    frames[count] = frame
    count+=1

# %%
healthy_df = pd.concat(frames).reset_index(drop=False)
# Out:
#    index        Ax        Ay        Az
# 0      0  0.119385  0.083252  0.888184
# 1      1  0.096924  0.097656  0.891602
# 2      2  0.104736  0.106445  0.948975
# 3      3  0.111816  0.086670  0.937988
# 4      4  0.098877  0.097168  0.902588

# %%
size = healthy_df.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time] - Curva 3')
axs[0].plot(range(0,size), healthy_df['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), healthy_df['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), healthy_df['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
healthy_df.to_csv('anomaly_train_dataset.csv')
healthy_df.shape
# Out:
# (4200, 4)

# %%
size = healthy.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), healthy['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), healthy['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), healthy['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-68a6d293961a> in <module>
# ----> 1 size = healthy.shape[0]
#       2 fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
#       3 fig.suptitle('Accelerometer Measures by Axis [time]')
#       4 axs[0].plot(range(0,size), healthy['Ax'], '-', color='blue', animated = True, linewidth=1)
#       5 axs[0].title.set_text('X axis')
#
# NameError: name 'healthy' is not defined

# %% [markdown]
# # Creating a random plain street with multiple sets of  healthy data to train NN-Anomaly detector

# %%
healthy2 = pd.concat(frames)
healthy2.head(50)

# %%
size = healthy2.shape[0]
fig, axs = plt.subplots(3,figsize=(16, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), healthy2['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), healthy2['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), healthy2['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))

# %%
healthy2.to_csv('anomaly_train_dataset.csv')

# %% [markdown]
# # Creating an artifitial dataset to test the anomaly detector

# %% [markdown]
# This dataset will have 3 stops, 3 potholes (strainers), and 3 curves without the slope the reference street has. The A.D. NN should detect only the stops and potholes with a close to 100% success rate, and without any false positive.

# %% [markdown]
# # Separating different kinds of anomalies to train SoftMax NN

# %% [markdown]
# Separating each tipe of anomaly, based on the position of the reference route

# %% [raw]
# 1- tope
# 2- coladera
# 3- curva

# %% [markdown]
# ## Baches (potholes)

# %%
plain1= pd.read_csv('rec_csv_file_plain_baches_street_1.csv')
size = plain1.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), plain1['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), plain1['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), plain1['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
#bache1.to_csv('bache1.csv')

# %%
#entre 155 y 170 aprox
bache1= pd.read_csv('rec_csv_file_plain_baches_street_1.csv').tail(250).head(30)
size = bache1.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), bache1['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), bache1['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), bache1['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
plain2= pd.read_csv('rec_csv_file_plain_baches_street_2.csv')
size = plain2.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), plain2['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), plain2['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), plain2['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
bache2_1= pd.read_csv('rec_csv_file_plain_baches_street_2.csv').tail(150).head(30)
size = bache2_1.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), bache2_1['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), bache2_1['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), bache2_1['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
bache2_1.to_csv('bache2_1.csv')

# %%
bache2_2= pd.read_csv('rec_csv_file_plain_baches_street_2.csv').tail(85).head(20)
size = bache2_2.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), bache2_2['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), bache2_2['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), bache2_2['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
plain3= pd.read_csv('rec_csv_file_plain_baches_street_3.csv')
size = plain3.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), plain3['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), plain3['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), plain3['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
bache3= pd.read_csv('rec_csv_file_plain_baches_street_3.csv').tail(150).head(40)
size = bache3.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), bache3['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), bache3['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), bache3['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
tope1= pd.read_csv('rec_csv_file_plain_street_1.csv').tail(75).head(50)
size = tope1.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), tope1['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), tope1['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), tope1['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
tope2= pd.read_csv('rec_csv_file_plain_baches_street_3_2.csv').tail(40)#.head(50)
size = tope2.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), tope2['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), tope2['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), tope2['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
tope3= pd.read_csv('rec_csv_file_plain_baches_street_3_2.csv').tail(40)#.head(50)
size = tope3.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), tope3['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), tope3['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), tope3['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
curva1= pd.read_csv('rec_csv_file__curva_1.csv')#.tail(40)#.head(50)
size = curva1.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), curva1['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), curva1['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), curva1['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
tope4= pd.read_csv('rec_csv_file__curva_1.csv').tail(300).head(50)
size = tope4.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), tope4['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), tope4['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), tope4['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
curva_1= pd.read_csv('rec_csv_file__curva_1.csv').tail(200)
size = curva_1.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), curva_1['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), curva_1['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), curva_1['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
curva2= pd.read_csv('rec_csv_file__curva_2.csv').tail(40)#.head(50)
size = curva2.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), curva2['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), curva2['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), curva2['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
tope5= pd.read_csv('rec_csv_file__curva_2.csv').tail(210).head(20)
size = tope5.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), tope5['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), tope5['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), tope5['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
curva_2= pd.read_csv('rec_csv_file__curva_2.csv').tail(150)
size = curva_2.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), curva_2['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), curva_2['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), curva_2['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
curva3= pd.read_csv('rec_csv_file__curva_3.csv')#.tail(40)#.head(50)
size = curva3.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), curva3['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), curva3['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), curva3['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
tope6= pd.read_csv('rec_csv_file__curva_3.csv').tail(210).head(20)
size = tope6.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), tope6['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), tope6['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), tope6['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
curva_3= pd.read_csv('rec_csv_file__curva_3.csv').tail(200)
size = curva_3.shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), curva_3['Ax'], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), curva_3['Ay'], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), curva_3['Az'], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %% [markdown]
# # Spectrum of anomalies

# %%
def removeOffset(array):  
    return  array - array.mean(axis=0, keepdims=True)

def reshape(data):
    data_scaled = scaleData(data)
    data_scaled = data_scaled.T
    return data_scaled

def createLabeledArray(data_fft, label, ammount):
    array= []
    count = 0
    length = 300
    loop = True
    while loop:
        if(count*length >=ammount):
            loop = False
            break
        a = np.hstack(((reshape(data_fft[count*300 : count*300+length])), label))
        if(count == 0):
            array = a
        else:
            array = np.vstack((array, a))
        count +=1
    return array

def createSections(df,label):
    npArray = np.array([df['Ax'].to_numpy(),df['Ay'].to_numpy(),df['Az'].to_numpy()])
    array=np.array([])
    size = 50 
    count = 0
    length = 300
    while count < npArray.shape[1]:
        a = npArray[0][count:count+size]
        b = npArray[1][count:count+size]
        c = npArray[2][count:count+size]
        Ax = singleRow(a,length)
        Ay = singleRow(b,length)
        Az = singleRow(c,length)
        Ax,Ay,Az = getFFTfrom3DArray(Ax,Ay,Az)
        if(array.shape[0] <=0 ):
            array = np.hstack(  (Ax,Ay,Az, label ) )
        else:
            temp = np.hstack(  (Ax,Ay,Az, label ) )
            array = np.vstack( (array, temp) )
        
        count= count+size 
    return array


def singleRow(numpyArr,length):
    a =numpyArr
    while a.shape[0] <length:
        a = np.hstack( (a,numpyArr)  )
    return a 

def getFFTfrom3DArray(np1,np2,np3):
    o_array1 = removeOffset(np1)
    o_array2 = removeOffset(np2)
    o_array3 = removeOffset(np3)
    fft1= np.square(np.abs(np.fft.rfft(o_array1)))
    fft2= np.square(np.abs(np.fft.rfft(o_array2)))
    fft3= np.square(np.abs(np.fft.rfft(o_array3)))
    return fft1,fft2,fft3




def createSectionsUnlabeled(df):
    npArray = np.array([df['Ax'].to_numpy(),df['Ay'].to_numpy(),df['Az'].to_numpy()])
    array=np.array([])
    size = 50 
    count = 0
    length = 300
    while count < npArray.shape[1]:
        a = npArray[0][count:count+size]
        b = npArray[1][count:count+size]
        c = npArray[2][count:count+size]
        Ax = singleRow(a,length)
        Ay = singleRow(b,length)
        Az = singleRow(c,length)
        Ax,Ay,Az = getFFTfrom3DArray(Ax,Ay,Az)
        if(array.shape[0] <=0 ):
            array = np.hstack(  (Ax,Ay,Az ) )
        else:
            temp = np.hstack(  (Ax,Ay,Az ) )
            array = np.vstack( (array, temp) )
        
        count= count+size 
    return array

# %%
def getFrequenciesPlotInfo(dataframe):
    sampling_rate = 1000.0
    dataAx= dataframe['Ax']
    dataAy= dataframe['Ay']
    dataAz= dataframe['Az']
    fourier_transform1 = np.fft.rfft(dataAx)
    fourier_transform2 = np.fft.rfft(dataAy)
    fourier_transform3 = np.fft.rfft(dataAz)
    abs_fourier_transform1 = np.abs(fourier_transform1)
    abs_fourier_transform2 = np.abs(fourier_transform2)
    abs_fourier_transform3 = np.abs(fourier_transform3)
    power_spectrum1 = np.square(abs_fourier_transform1)
    power_spectrum2 = np.square(abs_fourier_transform2)
    power_spectrum3 = np.square(abs_fourier_transform3)
    
    frequency = np.linspace(0, sampling_rate/2, len(power_spectrum1))
    return frequency,power_spectrum1,power_spectrum2,power_spectrum3

# %%
healthyPlotFirst50=  createSectionsUnlabeled(parkdf.head(50)) 
sampling_rate = 1000.0
frequency = np.linspace(0, sampling_rate/2, len(healthyPlotFirst50[0:151]))
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = int(len(healthyPlotFirst50)/3)
ax.plot(frequency, healthyPlotFirst50[0:151], '-', color='blue', animated = True, linewidth=1,label="Ax")

ax.plot(frequency, healthyPlotFirst50[151:302], '-', color='red', animated = True, linewidth=1,label="Ay")

ax.plot(frequency, healthyPlotFirst50[302:], '-', color='green', animated = True, linewidth=1,label="Az")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0.)
plt.title('Power Spectrum of parked vehicle')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power spectrum')
plt.ylim(0.0,20)
# Out:
# (0.0, 20.0)

# %%
healthyPlotFirst50=  createSectionsUnlabeled(df_plain_2.head(100).tail(50)) 
sampling_rate = 1000.0
frequency = np.linspace(0, sampling_rate/2, len(healthyPlotFirst50[0:151]))
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = int(len(healthyPlotFirst50)/3)
ax.plot(frequency, healthyPlotFirst50[0:151], '-', color='blue', animated = True, linewidth=1,label="Ax")

ax.plot(frequency, healthyPlotFirst50[151:302], '-', color='red', animated = True, linewidth=1,label="Ay")

ax.plot(frequency, healthyPlotFirst50[302:], '-', color='green', animated = True, linewidth=1,label="Az")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0.)
plt.title('Power Spectrum of dataset with no anomalies at 25 km/h lap')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power spectrum')
plt.ylim(0.0,25)
# Out:
# (0.0, 25.0)

# %%
healthyPlotFirst50=  createSectionsUnlabeled(curva2.head(50)) 
sampling_rate = 1000.0
frequency = np.linspace(0, sampling_rate/2, len(healthyPlotFirst50[0:151]))
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = int(len(healthyPlotFirst50)/3)
ax.plot(frequency, healthyPlotFirst50[0:151], '-', color='blue', animated = True, linewidth=1,label="Ax")

ax.plot(frequency, healthyPlotFirst50[151:302], '-', color='red', animated = True, linewidth=1,label="Ay")

ax.plot(frequency, healthyPlotFirst50[302:453], '-', color='green', animated = True, linewidth=1,label="Az")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0.)
plt.title('Power Spectrum of dataset with steep curve at 25 km/h lap')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power spectrum')
plt.ylim(0.0,120)
# Out:
# (0.0, 120.0)

# %%
healthyPlotFirst50=  createSectionsUnlabeled(bache2_1.head(50)) 
sampling_rate = 1000.0
frequency1 = np.linspace(0, sampling_rate/2, len(healthyPlotFirst50[0:151]))
frequency2 = np.linspace(0, sampling_rate/2, len(healthyPlotFirst50[151:302]))


fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = int(len(healthyPlotFirst50)/3)
ax.plot(frequency1, healthyPlotFirst50[0:151], '-', color='blue', animated = True, linewidth=1,label="Ax")

ax.plot(frequency2, healthyPlotFirst50[151:302], '-', color='red', animated = True, linewidth=1,label="Ay")

ax.plot(frequency, healthyPlotFirst50[302:], '-', color='green', animated = True, linewidth=1,label="Az")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0.)
plt.title('Power Spectrum of dataset only one pothole')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power spectrum')
plt.ylim(0.0,400)
# Out:
# (0.0, 400.0)

# %%
healthyPlotFirst50=  createSectionsUnlabeled(tope2.head(50)) 
sampling_rate = 1000.0
frequency = np.linspace(0, sampling_rate/2, len(healthyPlotFirst50[0:151]))
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = int(len(healthyPlotFirst50)/3)
ax.plot(frequency, healthyPlotFirst50[0:151], '-', color='blue', animated = True, linewidth=1,label="Ax")

ax.plot(frequency, healthyPlotFirst50[151:302], '-', color='red', animated = True, linewidth=1,label="Ay")

ax.plot(frequency, healthyPlotFirst50[302:453], '-', color='green', animated = True, linewidth=1,label="Az")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0.)
plt.title('Power Spectrum of dataset with speed bump at 25km/h lap')
plt.xlabel('Frequency (Hz)') 
plt.ylabel('Power spectrum')
plt.ylim(0.0,800)
# Out:
# (0.0, 800.0)

# %% [markdown]
# ## data synth

# %%
def treatFrames(frames):
    count = 0
    for  frame in frames:
        while frame.shape[0] < 300:
            frame = pd.concat([frame,frame])
        frame = frame.head(300)
        frames[count] = frame
        count+=1
    return frames

# %%
frames_broken = [bache1,tope6,curva_1,tope1,bache2_1,tope6,curva_2,tope2,bache2_2,bache3,tope2,curva_1,  tope1,bache1,curva_3,tope2,bache2_1,curva_2,tope3,tope4,curva_3,bache3,tope5,bache2_1,tope6,bache1,curva_1,tope1,bache3,tope4,curva_2,tope4,curva_3]
frames_baches = [bache1,bache2_1,bache2_2,bache3,bache1,bache2_1,bache3,bache2_1,bache1,bache3] #modiificar desps con time shifts
frames_topes = [tope6,tope1,tope6,tope2,tope5,tope2,tope1,tope2,tope3,tope4,tope5,tope6,tope1,tope4,tope4,tope5]
frames_curvas = [curva_1,curva_2,curva_1,curva_3,curva_2,curva_3,curva_1,curva_2,curva_3]

frames_baches = treatFrames(frames_baches)
frames_topes = treatFrames(frames_topes)
frames_curvas = treatFrames(frames_curvas)
baches = pd.concat(frames_baches)
curvas = pd.concat(frames_curvas)
topes = pd.concat(frames_topes)

# %%
print( baches.shape)
print (topes.shape)
print (curvas.shape)
# Out:
# (3000, 9)
# (4800, 9)
# (2700, 9)

# %%
baches.to_csv('softmax_baches.csv')
topes.to_csv('softmax_topes.csv')
curvas.to_csv('softmax_curvas.csv')

# %%
size = baches[:600].shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), baches['Ax'][:600], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), baches['Ay'][:600], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), baches['Az'][:600], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
size = curvas[:600].shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), curvas['Ax'][:600], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), curvas['Ay'][:600], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), curvas['Az'][:600], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))
# Out:
# (0.5, 1.5)

# %%
size = topes[:600].shape[0]
fig, axs = plt.subplots(3,figsize=(6, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Accelerometer Measures by Axis [time]')
axs[0].plot(range(0,size), topes['Ax'][:600], '-', color='blue', animated = True, linewidth=1)
axs[0].title.set_text('X axis')
axs[1].plot(range(0,size), topes['Ay'][:600], '-', color='red', animated = True, linewidth=1)
axs[1].title.set_text('Y axis')
axs[2].plot(range(0,size), topes['Az'][:600], '-', color='green', animated = True, linewidth=1)
axs[2].title.set_text('Z axis')
axs[0].set_ylim(( -0.7,1 ))
axs[1].set_ylim(( -0.5,1 ))
axs[2].set_ylim(( 0.5,1.5 ))

# %% [markdown]
# ## Creating both a healthy and faulty test dataset
